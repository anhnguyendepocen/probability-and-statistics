# %% [markdown]
# # Exploratory Data Analysis: Examining Relationships

# %% [markdown]
# ### Q -> Q

# %% [markdown]
# _Using Python_

# %%
import pandas as pd
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
data = pd.read_excel('files/height.xls')
data.head()
# Out:
#    gender  height  weight
# 0       0      72     155
# 1       0      67     145
# 2       0      65     125
# 3       1      67     120
# 4       1      63     105

# %%
data = data.sort_values(by='gender')
data.head()
# Out:
#     gender  height  weight
# 0        0      72     155
# 58       0      72     230
# 57       0      72     163
# 56       0      72     198
# 55       0      72     170

# %%
ht_vs_wt = [go.Scatter(x=data.height, y=data.weight, mode='markers')]
layout = go.Layout(
    title='Height vs Weight',
    xaxis={'title': 'Height(inches)'},
    yaxis={'title': 'Weight(lbs)'},
)

figure = go.Figure(data=ht_vs_wt, layout=layout)
iplot(figure)
# Out:
# <div id="f58e4092-14da-456b-8db2-8e36fd23f2b1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f58e4092-14da-456b-8db2-8e36fd23f2b1", [{"type": "scatter", "x": [72, 72, 72, 72, 72, 73, 68, 75, 74, 68, 67, 66, 67, 69, 68, 71, 71, 72, 68, 68, 68, 67, 70, 71, 70, 67, 68, 72, 73, 68, 72, 71, 67, 67, 70, 72, 70, 73, 69, 73, 72, 72, 71, 71, 66, 66, 72, 73, 67, 70, 65, 65, 67, 73, 69, 70, 68, 63, 66, 64, 67, 57, 66, 54, 58, 68, 65, 70, 64, 64, 63, 60, 69, 65, 67, 62, 66, 65, 63, 67, 56], "y": [155, 230, 163, 198, 170, 240, 149, 230, 170, 155, 150, 135, 146, 185, 158, 175, 185, 160, 155, 151, 145, 167, 155, 175, 200, 150, 150, 181, 220, 170, 205, 237, 185, 145, 210, 160, 130, 147, 168, 172, 180, 170, 175, 205, 175, 133, 160, 163, 120, 175, 130, 125, 145, 195, 135, 145, 140, 105, 125, 125, 120, 82, 125, 120, 100, 133, 107, 170, 110, 140, 110, 110, 125, 120, 180, 122, 114, 115, 125, 133, 100], "mode": "markers"}], {"title": "Height vs Weight", "xaxis": {"title": "Height(inches)"}, "yaxis": {"title": "Weight(lbs)"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ##### Labelled Scatter plot

# %%
ht_vs_wt_male = go.Scatter(x=data.height[data.gender==1], y=data.weight[data.gender==1], mode='markers', name="Male")
ht_vs_wt_female = go.Scatter(x=data.height[data.gender==0], y=data.weight[data.gender==0], mode='markers', name="Female")

# %%
figure = go.Figure(data=[ht_vs_wt_female, ht_vs_wt_male], layout=layout)

# %%
iplot(figure)
# Out:
# <div id="2f51bcca-ef4d-4254-b6b0-f7a3f7534cc3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("2f51bcca-ef4d-4254-b6b0-f7a3f7534cc3", [{"type": "scatter", "x": [72, 72, 72, 72, 72, 73, 68, 75, 74, 68, 67, 66, 67, 69, 68, 71, 71, 72, 68, 68, 68, 67, 70, 71, 70, 67, 68, 72, 73, 68, 72, 71, 67, 67, 70, 72, 70, 73, 69, 73, 72, 72, 71, 71, 66, 66, 72, 73, 67, 70, 65, 65, 67, 73, 69, 70, 68], "y": [155, 230, 163, 198, 170, 240, 149, 230, 170, 155, 150, 135, 146, 185, 158, 175, 185, 160, 155, 151, 145, 167, 155, 175, 200, 150, 150, 181, 220, 170, 205, 237, 185, 145, 210, 160, 130, 147, 168, 172, 180, 170, 175, 205, 175, 133, 160, 163, 120, 175, 130, 125, 145, 195, 135, 145, 140], "mode": "markers", "name": "Female"}, {"type": "scatter", "x": [63, 66, 64, 67, 57, 66, 54, 58, 68, 65, 70, 64, 64, 63, 60, 69, 65, 67, 62, 66, 65, 63, 67, 56], "y": [105, 125, 125, 120, 82, 125, 120, 100, 133, 107, 170, 110, 140, 110, 110, 125, 120, 180, 122, 114, 115, 125, 133, 100], "mode": "markers", "name": "Male"}], {"title": "Height vs Weight", "xaxis": {"title": "Height(inches)"}, "yaxis": {"title": "Weight(lbs)"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ### Q -> Q: Linear Relatioships

# %%
animals = pd.read_excel('files/animals.xls')
animals.head()
# Out:
#           animal  gestation  longevity
# 0         baboon        187         20
# 1    bear, black        219         18
# 2  bear, grizzly        225         25
# 3    bear, polar        240         20
# 4         beaver        122          5

# %% [markdown]
# Correlation is only a measure of linear relationship, so first we plot a graph to check for the type of relationship between gestation period and longetivity

# %%
data = [go.Scatter(x=animals.gestation, y=animals.longevity, text=animals.animal, mode='markers')]
layout = go.Layout(
    xaxis={'title': 'Average Longevity of Species (years)'},
    yaxis={'title': 'Average Gestation Period of Species (days)'}
)
iplot(go.Figure(data=data, layout=layout))
# Out:
# <div id="0ab3f21f-62ac-4cee-8ed1-14c8727cd480" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0ab3f21f-62ac-4cee-8ed1-14c8727cd480", [{"type": "scatter", "x": [187, 219, 225, 240, 122, 278, 406, 63, 231, 31, 284, 201, 61, 365, 645, 250, 52, 425, 151, 257, 68, 238, 330, 42, 98, 100, 164, 240, 21, 15, 112, 90, 31, 450, 350, 154, 44, 105, 63, 365], "y": [20, 18, 25, 20, 5, 15, 12, 12, 20, 6, 15, 8, 12, 12, 40, 15, 7, 10, 8, 20, 4, 25, 20, 7, 12, 15, 15, 12, 3, 1, 10, 12, 5, 15, 12, 12, 10, 16, 5, 15], "text": ["baboon", "bear, black", "bear, grizzly", "bear, polar", "beaver", "buffalo", "camel", "cat", "chimpanzee", "chipmunk", "cow", "deer", "dog", "donkey", "elephant", "elk", "fox", "giraffe", "goat", "gorilla", "guinea pig", "hippopotamus", "horse", "kangaroo", "leopard", "lion", "monkey", "moose", "mouse", "opossum", "pig", "puma", "rabbit", "rhinoceros", "sea lion", "sheep", "squirrel", "tiger", "wolf", "zebra"], "mode": "markers"}], {"xaxis": {"title": "Average Longevity of Species (years)"}, "yaxis": {"title": "Average Gestation Period of Species (days)"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
r = animals.longevity.corr(animals.gestation)
print(f"Correlation Coefficient = {r}")
# Out:
# Correlation Coefficient = 0.6632396748585047

# %% [markdown]
# The outlier(elephant) may be affecting the correlation in some way. Let us check how

# %%
r = animals.longevity[animals.animal != 'elephant'].corr(animals.gestation[animals.animal != 'elephant'])
print(f"Correlation Coefficient without elephant = {r}")
# Out:
# Correlation Coefficient without elephant = 0.5190389111466761

# %% [markdown]
# ### Q -> Q Linear Regression

# %%
from sklearn import linear_model
from scipy.stats import linregress

# %%
olympics = pd.read_excel('files/olympics_2012.xls')
olympics.head()
# Out:
#    Year   Time
# 0  1896  273.2
# 1  1900  246.0
# 2  1904  245.4
# 3  1908  243.4
# 4  1912  236.8

# %%
year_vs_time = go.Scatter(x=olympics.Year, y=olympics.Time, name='Data', mode='markers')
layout = go.Layout(xaxis=go.XAxis(title='Year of Olympic Games'), 
                   yaxis=go.YAxis(title='Winning Time of 1500m Race (secs)'))

iplot(go.Figure(data=[year_vs_time], layout=layout))
# Out:
# <div id="3a2e2056-f041-4cb5-8d60-67d793bdf870" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3a2e2056-f041-4cb5-8d60-67d793bdf870", [{"type": "scatter", "x": [1896, 1900, 1904, 1908, 1912, 1920, 1924, 1928, 1932, 1936, 1948, 1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012], "y": [273.2, 246.0, 245.4, 243.4, 236.8, 241.8, 233.6, 233.2, 231.2, 227.8, 229.8, 225.1, 221.2, 215.6, 218.1, 214.9, 216.3, 219.2, 218.4, 212.53, 215.96, 220.12, 215.78, 212.07, 214.19, 213.11, 214.08], "name": "Data", "mode": "markers"}], {"xaxis": {"title": "Year of Olympic Games"}, "yaxis": {"title": "Winning Time of 1500m Race (secs)"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
least_sq_reg = linregress(olympics.Year, olympics.Time)

# %%
line = olympics.Year * least_sq_reg.slope + least_sq_reg.intercept

# %%
reg_line = go.Scatter(x=olympics.Year, y=line, name="Regression Line")

# %%
iplot(go.Figure(data=[year_vs_time, reg_line], layout=layout))
# Out:
# <div id="b2343d8b-e3d4-4a80-8d9f-b55988ae9c44" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b2343d8b-e3d4-4a80-8d9f-b55988ae9c44", [{"type": "scatter", "x": [1896, 1900, 1904, 1908, 1912, 1920, 1924, 1928, 1932, 1936, 1948, 1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012], "y": [273.2, 246.0, 245.4, 243.4, 236.8, 241.8, 233.6, 233.2, 231.2, 227.8, 229.8, 225.1, 221.2, 215.6, 218.1, 214.9, 216.3, 219.2, 218.4, 212.53, 215.96, 220.12, 215.78, 212.07, 214.19, 213.11, 214.08], "name": "Data", "mode": "markers"}, {"type": "scatter", "x": [1896, 1900, 1904, 1908, 1912, 1920, 1924, 1928, 1932, 1936, 1948, 1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012], "y": [247.525794004104, 246.1145988244706, 244.70340364483707, 243.29220846520366, 241.88101328557025, 239.05862292630343, 237.6474277466699, 236.2362325670365, 234.82503738740309, 233.41384220776968, 229.18025666886933, 227.76906148923592, 226.3578663096025, 224.9466711299691, 223.5354759503357, 222.12428077070228, 220.71308559106876, 219.30189041143535, 217.89069523180194, 216.47950005216853, 215.06830487253512, 213.6571096929016, 212.2459145132682, 210.83471933363478, 209.42352415400137, 208.01232897436796, 206.60113379473455], "name": "Regression Line"}], {"xaxis": {"title": "Year of Olympic Games"}, "yaxis": {"title": "Winning Time of 1500m Race (secs)"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
print(f"Equation of regression line is Y = {least_sq_reg.slope:.2f} * X + {least_sq_reg.intercept:.2f}")
# Out:
# Equation of regression line is Y = -0.35 * X + 916.43

# %% [markdown]
# We see that there is an outlier which is the year 1896. Lets check the effect of the outlier on the relationship

# %%
olympics_from_1900 = olympics[olympics.Year >= 1900]
olympics_from_1900.head()
# Out:
#    Year   Time
# 1  1900  246.0
# 2  1904  245.4
# 3  1908  243.4
# 4  1912  236.8
# 5  1920  241.8

# %%
trace_xy = go.Scatter(x=olympics_from_1900.Year, y=olympics_from_1900.Time, mode='markers', name="Data")
iplot(go.Figure(data=[trace_xy], layout=layout))
# Out:
# <div id="cc0117f3-ef11-4490-9d2f-f711b1819498" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cc0117f3-ef11-4490-9d2f-f711b1819498", [{"type": "scatter", "x": [1900, 1904, 1908, 1912, 1920, 1924, 1928, 1932, 1936, 1948, 1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012], "y": [246.0, 245.4, 243.4, 236.8, 241.8, 233.6, 233.2, 231.2, 227.8, 229.8, 225.1, 221.2, 215.6, 218.1, 214.9, 216.3, 219.2, 218.4, 212.53, 215.96, 220.12, 215.78, 212.07, 214.19, 213.11, 214.08], "mode": "markers", "name": "Data"}], {"xaxis": {"title": "Year of Olympic Games"}, "yaxis": {"title": "Winning Time of 1500m Race (secs)"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
lm = linear_model.LinearRegression()
lm.fit(olympics_from_1900.Year.reshape([-1, 1]), olympics_from_1900.Time)
slope, intercept = lm.coef_[0], lm.intercept_
# Out:
# /Users/dhoomilbsheta/miniconda3/envs/deepl/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning:
#
# reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#
# /Users/dhoomilbsheta/miniconda3/envs/deepl/lib/python3.6/site-packages/sklearn/linear_model/base.py:509: RuntimeWarning:
#
# internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.

# %%
print(f"Equation of regression line is Y = {slope:.2f} * X + {intercept:.2f}")
# Out:
# Equation of regression line is Y = -0.30 * X + 811.54

# %%
line = slope*olympics_from_1900.Year + intercept
reg_line = go.Scatter(x=olympics_from_1900.Year, y=line, name="Regression Line")
iplot(go.Figure(data=[trace_xy, reg_line], layout=layout))
# Out:
# <div id="5838d0c2-e2f8-4322-95c7-02e1deeec2aa" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5838d0c2-e2f8-4322-95c7-02e1deeec2aa", [{"type": "scatter", "x": [1900, 1904, 1908, 1912, 1920, 1924, 1928, 1932, 1936, 1948, 1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012], "y": [246.0, 245.4, 243.4, 236.8, 241.8, 233.6, 233.2, 231.2, 227.8, 229.8, 225.1, 221.2, 215.6, 218.1, 214.9, 216.3, 219.2, 218.4, 212.53, 215.96, 220.12, 215.78, 212.07, 214.19, 213.11, 214.08], "mode": "markers", "name": "Data"}, {"type": "scatter", "x": [1900, 1904, 1908, 1912, 1920, 1924, 1928, 1932, 1936, 1948, 1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012], "y": [242.0174458276639, 240.81846002315137, 239.61947421863897, 238.42048841412645, 236.02251680510142, 234.8235310005889, 233.62454519607638, 232.42555939156387, 231.22657358705146, 227.6296161735139, 226.4306303690014, 225.23164456448887, 224.03265875997647, 222.83367295546395, 221.63468715095144, 220.43570134643892, 219.2367155419264, 218.03772973741388, 216.83874393290148, 215.63975812838896, 214.44077232387644, 213.24178651936393, 212.0428007148514, 210.8438149103389, 209.64482910582637, 208.44584330131397], "name": "Regression Line"}], {"xaxis": {"title": "Year of Olympic Games"}, "yaxis": {"title": "Winning Time of 1500m Race (secs)"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
print(f"Prediction for 1,500 meter time in the 2016 Olympic Games in Rio de Janeiro is {slope*2016 + intercept:.2f}secs")
# Out:
# Prediction for 1,500 meter time in the 2016 Olympic Games in Rio de Janeiro is 207.25secs

# %% [markdown]
# ## StatTutor

# %% [markdown]
# A student survey was conducted at a major university. Data were collected from a random sample of 239 undergraduate students, and the information that was collected included physical characteristics (such as height, handedness, etc.), study habits, academic performance and attitudes, and social behaviors. In this exercise, we will focus on exploring relationships between some of those variables. Note that the symbol * in the worksheet means that this observation is not available (this is known as a 'missing value').

# %% [markdown]
# **Gender:** Male or Female
# **Height:** Self-reported height (in inches)
# **GPA:** Student's cumulative college GPA
# **HS_GPA:** Student's high school GPA (senior year)
# **Seat:** Typical classroom seat location (F = Front, M = Middle, B = Back)
# **WtFeel:** Does the student feel that he/she is: Underweight, About Right, Overweight
# **Cheat:** Would the tell the instructor if he/she saw somebody cheating on exam? (No or Yes)

# %% [markdown]
# ### 1. Understanding the Problem: Check Data Format

# %%
students = pd.read_excel('files/body_image.xls')
students = students.replace({'*': None})
students.head(10)
# Out:
#    Gender  Height   GPA  HS GPA Seat   WtFeel Cheat
# 0  Female    64.0  2.60    2.63    M  AboutRt    No
# 1    Male    69.0  2.70    3.72    M  AboutRt    No
# 2  Female    66.0  3.00    3.44    F  AboutRt    No
# 3  Female    63.0  3.11    2.73    F  AboutRt    No
# 4    Male    72.0  3.40    2.35    B   OverWt    No
# 5  Female    67.0  3.43    3.84    M  AboutRt    No
# 6    Male    69.0  3.70    4.00    F      NaN    No
# 7    Male    74.0  3.70    3.92    B  AboutRt    No
# 8    Male    72.0  3.77    3.09    M  UnderWt    No
# 9  Female    63.0  3.50    4.00    F  AboutRt    No

# %% [markdown]
# ### Q1. Is there a relationship between students' college GPAs and their high school GPAs?

# %% [markdown]
# #### 1. Reflect on Question
# In this first step, we think about the question and use our intuition and/or experience to try and predict what the results will show. Later, we will compare what we initially thought to what we actually find when we analyze the data.

# %% [markdown]
# >Yes. Generally students performing well will continue to perform well in college. There might be some dip in GPA maybe due to distractions in the college

# %% [markdown]
# #### 2. Analyze Data

# %% [markdown]
# ##### a. Plan Analyses

# %% [markdown]
# Before choosing the appropriate analyses, it is helpful to identify the relevant variables, which for this question are:
# - GPA
# - HS_GPA
#
# The variable **GPA** is *independent (response)* variable and is *quantitative*.
# The variable **HS GPA** is *dependent (explanatory)* variable and is *quantitative*

# %% [markdown]
# ##### b. Exploratory Analysis
# - A meaningful display for this question is *Scatterplot*.
# - A meaningful numerical summary to supplement the above display is *Correlation (if relationship is linear)
# - Using this display and numerical summary, I will describe relationship between two quantitative variables

# %% [markdown]
# *Scatterplot*

# %%
trace_1 = go.Scatter(x=students['HS GPA'], y=students['GPA'], mode='markers', name='Data')
layout = go.Layout(
    title='College GPA vs High School GPA',
    xaxis={'title': 'High School GPA'},
    yaxis={'title': 'College GPA'}
)

# %%
iplot(go.Figure(data=[trace_1], layout=layout))
# Out:
# <div id="b88dd14b-ca8c-484d-8879-f03c4008408e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b88dd14b-ca8c-484d-8879-f03c4008408e", [{"type": "scatter", "x": [2.63, 3.72, 3.44, 2.73, 2.35, 3.84, 4.0, 3.92, 3.09, 4.0, 3.43, 3.62, 3.49, 3.09, 3.22, 2.52, 2.36, 4.0, 4.0, 4.0, 3.54, 4.0, 3.08, 2.49, 3.6, 3.5, 3.22, null, 3.66, 3.02, 2.84, null, 3.03, 3.49, 3.21, 3.43, 2.63, 2.65, null, 3.98, 2.7, 2.86, 3.91, 3.63, 3.11, 3.34, 3.52, 3.55, 3.47, 3.27, 4.0, 3.9, 2.98, 2.96, null, 3.81, 4.0, 2.71, 3.05, 2.33, 3.38, 3.48, 3.93, 3.45, 3.19, 3.87, 3.28, 3.76, null, 2.75, 4.0, 4.0, 4.0, 2.57, 2.12, 3.41, 4.0, 2.87, 2.97, 3.31, 2.91, 4.0, 3.43, 1.49, 3.71, 3.48, 2.94, 4.0, 2.87, 4.0, 3.04, 3.37, 3.53, 3.75, 3.28, 3.67, 3.95, 4.0, 2.62, 2.77, 3.54, 4.0, 2.32, 2.65, 3.54, 3.03, 3.61, 4.0, 3.79, 1.95, 2.08, 2.18, 3.34, 2.27, 3.79, 2.7, 4.0, 3.94, 3.31, 2.42, 1.89, 4.0, 4.0, 2.26, 2.48, 3.82, 2.93, null, 1.52, 3.3, 3.23, 3.94, 2.46, 2.72, 3.17, 2.81, 2.83, 4.0, 4.0, 3.34, 4.0, 2.69, 2.52, 3.65, 3.45, 2.52, 3.04, 2.8, 4.0, 3.87, 3.73, null, 3.96, 4.0, 2.45, 4.0, 3.46, 3.42, 3.54, 3.48, 3.9, 3.0, 3.32, 2.82, 2.41, 3.98, 2.98, 3.3, 4.0, 3.73, 4.0, 3.9, 4.0, 4.0, 4.0, 4.0, 2.73, 3.81, 2.01, 3.06, 2.67, 4.0, 2.85, 2.75, 3.11, 2.1, 4.0, 3.5, 2.93, 3.09, 4.0, 2.92, 4.0, null, 3.43, 4.0, 3.74, 4.0, 4.0, 4.0, 2.66, 3.43, 3.98, 4.0, 3.49, 4.0, 3.71, 4.0, 2.99, 2.54, 4.0, 3.8, 4.0, 3.26, 3.58, 3.35, 3.85, 4.0, 2.86, 2.99, 2.21, 3.31, 4.0, 3.49, 3.44, 3.29, 2.67, 3.72, 3.18, 2.24, 2.09, 2.61, 4.0, 2.07, 1.83, 2.06], "y": [2.6, 2.7, 3.0, 3.11, 3.4, 3.43, 3.7, 3.7, 3.77, 3.5, 3.0, 3.0, 3.5, 3.25, 2.83, 2.62, 3.15, 4.2, 3.7, 4.38, 3.65, 3.6, 3.0, 2.25, 4.03, 2.54, 2.6, null, 3.0, 2.93, 3.2, null, 3.0, 3.4, 2.5, 3.0, 3.51, 2.37, null, 3.5, 3.0, 2.9, 3.9, 2.65, 3.5, 3.3, 3.4, 3.6, 3.21, 3.1, 3.85, 3.2, 2.5, 2.5, null, 2.9, 4.2, 2.8, 2.6, 3.05, 3.7, 4.0, 3.5, 3.22, 2.9, 3.25, 3.26, 3.0, null, 2.01, 3.71, 3.87, 3.26, 2.5, 2.9, 3.6, 3.9, 2.0, 3.2, 3.3, 2.8, 3.8, 3.0, 2.23, 3.876, 3.01, 2.5, 3.0, 2.79, 3.8, 3.25, 2.8, 3.39, 2.64, 3.65, 3.4, 3.33, 3.9, 2.54, 2.8, 3.5, 3.1, 2.66, 1.91, 2.8, 2.8, 2.7, 3.8, 3.24, 2.58, 3.17, 2.6, 2.58, 2.0, 3.44, 2.9, 2.7, 3.5, 3.0, 2.44, 2.0, 3.34, 3.83, 1.92, 2.7, 3.9, 2.33, null, 1.96, 3.0, 3.0, 3.4, 2.05, 3.1, 3.0, 3.0, 3.25, 3.92, 4.0, 3.0, 3.26, 2.8, 2.84, 2.8, 2.87, 2.1, 2.77, 2.95, 3.7, 3.89, 3.5, null, 3.0, 3.88, 3.0, 4.0, 3.2, 3.2, 3.57, 3.0, 2.96, 2.5, 2.67, 3.0, 2.7, 3.8, 2.5, 3.1, 3.5, 3.87, 3.4, 4.1, 3.54, 3.8, 3.21, 3.0, 2.04, 2.8, 2.4, 2.9, 2.38, 3.83, 2.9, 2.91, 2.9, 2.04, 3.67, 3.0, 3.3, 3.6, 3.5, 3.0, 3.7, null, 3.4, 3.33, 4.06, 3.8, 4.0, 3.0, 3.0, 3.0, 3.2, 3.4, 3.5, 3.6, 3.43, 3.92, 3.0, 2.9, 3.2, 3.4, 3.7, 3.4, 3.1, 3.0, 3.79, 3.9, 2.1, 3.0, 2.06, 3.0, 3.81, 2.4, 2.6, 3.0, 3.0, 3.9, 2.94, 2.5, 2.5, 2.7, 3.2, 2.67, 2.0, 2.46], "mode": "markers", "name": "Data"}], {"title": "College GPA vs High School GPA", "xaxis": {"title": "High School GPA"}, "yaxis": {"title": "College GPA"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
r_gpa = students['HS GPA'].corr(students['GPA'])
print("Correlation between High School GPA and College GPA is", r_gpa)
# Out:
# Correlation between High School GPA and College GPA is 0.715547363422

# %%
mask = ~students['HS GPA'].isna() & ~students['GPA'].isna()

# %%
lm = linregress(x=students['HS GPA'][mask], y=students['GPA'][mask])
slope, intercept = lm.slope, lm.intercept
gpa_pred = slope * students['HS GPA'] + intercept

# %%
trace_2 = go.Scatter(x=students['HS GPA'], y=gpa_pred, name="Regression Line")

iplot(go.Figure(data=[trace_1, trace_2], layout=layout))
# Out:
# <div id="ba0f8b29-d7cb-4413-8c1c-b320d0033988" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ba0f8b29-d7cb-4413-8c1c-b320d0033988", [{"type": "scatter", "x": [2.63, 3.72, 3.44, 2.73, 2.35, 3.84, 4.0, 3.92, 3.09, 4.0, 3.43, 3.62, 3.49, 3.09, 3.22, 2.52, 2.36, 4.0, 4.0, 4.0, 3.54, 4.0, 3.08, 2.49, 3.6, 3.5, 3.22, null, 3.66, 3.02, 2.84, null, 3.03, 3.49, 3.21, 3.43, 2.63, 2.65, null, 3.98, 2.7, 2.86, 3.91, 3.63, 3.11, 3.34, 3.52, 3.55, 3.47, 3.27, 4.0, 3.9, 2.98, 2.96, null, 3.81, 4.0, 2.71, 3.05, 2.33, 3.38, 3.48, 3.93, 3.45, 3.19, 3.87, 3.28, 3.76, null, 2.75, 4.0, 4.0, 4.0, 2.57, 2.12, 3.41, 4.0, 2.87, 2.97, 3.31, 2.91, 4.0, 3.43, 1.49, 3.71, 3.48, 2.94, 4.0, 2.87, 4.0, 3.04, 3.37, 3.53, 3.75, 3.28, 3.67, 3.95, 4.0, 2.62, 2.77, 3.54, 4.0, 2.32, 2.65, 3.54, 3.03, 3.61, 4.0, 3.79, 1.95, 2.08, 2.18, 3.34, 2.27, 3.79, 2.7, 4.0, 3.94, 3.31, 2.42, 1.89, 4.0, 4.0, 2.26, 2.48, 3.82, 2.93, null, 1.52, 3.3, 3.23, 3.94, 2.46, 2.72, 3.17, 2.81, 2.83, 4.0, 4.0, 3.34, 4.0, 2.69, 2.52, 3.65, 3.45, 2.52, 3.04, 2.8, 4.0, 3.87, 3.73, null, 3.96, 4.0, 2.45, 4.0, 3.46, 3.42, 3.54, 3.48, 3.9, 3.0, 3.32, 2.82, 2.41, 3.98, 2.98, 3.3, 4.0, 3.73, 4.0, 3.9, 4.0, 4.0, 4.0, 4.0, 2.73, 3.81, 2.01, 3.06, 2.67, 4.0, 2.85, 2.75, 3.11, 2.1, 4.0, 3.5, 2.93, 3.09, 4.0, 2.92, 4.0, null, 3.43, 4.0, 3.74, 4.0, 4.0, 4.0, 2.66, 3.43, 3.98, 4.0, 3.49, 4.0, 3.71, 4.0, 2.99, 2.54, 4.0, 3.8, 4.0, 3.26, 3.58, 3.35, 3.85, 4.0, 2.86, 2.99, 2.21, 3.31, 4.0, 3.49, 3.44, 3.29, 2.67, 3.72, 3.18, 2.24, 2.09, 2.61, 4.0, 2.07, 1.83, 2.06], "y": [2.6, 2.7, 3.0, 3.11, 3.4, 3.43, 3.7, 3.7, 3.77, 3.5, 3.0, 3.0, 3.5, 3.25, 2.83, 2.62, 3.15, 4.2, 3.7, 4.38, 3.65, 3.6, 3.0, 2.25, 4.03, 2.54, 2.6, null, 3.0, 2.93, 3.2, null, 3.0, 3.4, 2.5, 3.0, 3.51, 2.37, null, 3.5, 3.0, 2.9, 3.9, 2.65, 3.5, 3.3, 3.4, 3.6, 3.21, 3.1, 3.85, 3.2, 2.5, 2.5, null, 2.9, 4.2, 2.8, 2.6, 3.05, 3.7, 4.0, 3.5, 3.22, 2.9, 3.25, 3.26, 3.0, null, 2.01, 3.71, 3.87, 3.26, 2.5, 2.9, 3.6, 3.9, 2.0, 3.2, 3.3, 2.8, 3.8, 3.0, 2.23, 3.876, 3.01, 2.5, 3.0, 2.79, 3.8, 3.25, 2.8, 3.39, 2.64, 3.65, 3.4, 3.33, 3.9, 2.54, 2.8, 3.5, 3.1, 2.66, 1.91, 2.8, 2.8, 2.7, 3.8, 3.24, 2.58, 3.17, 2.6, 2.58, 2.0, 3.44, 2.9, 2.7, 3.5, 3.0, 2.44, 2.0, 3.34, 3.83, 1.92, 2.7, 3.9, 2.33, null, 1.96, 3.0, 3.0, 3.4, 2.05, 3.1, 3.0, 3.0, 3.25, 3.92, 4.0, 3.0, 3.26, 2.8, 2.84, 2.8, 2.87, 2.1, 2.77, 2.95, 3.7, 3.89, 3.5, null, 3.0, 3.88, 3.0, 4.0, 3.2, 3.2, 3.57, 3.0, 2.96, 2.5, 2.67, 3.0, 2.7, 3.8, 2.5, 3.1, 3.5, 3.87, 3.4, 4.1, 3.54, 3.8, 3.21, 3.0, 2.04, 2.8, 2.4, 2.9, 2.38, 3.83, 2.9, 2.91, 2.9, 2.04, 3.67, 3.0, 3.3, 3.6, 3.5, 3.0, 3.7, null, 3.4, 3.33, 4.06, 3.8, 4.0, 3.0, 3.0, 3.0, 3.2, 3.4, 3.5, 3.6, 3.43, 3.92, 3.0, 2.9, 3.2, 3.4, 3.7, 3.4, 3.1, 3.0, 3.79, 3.9, 2.1, 3.0, 2.06, 3.0, 3.81, 2.4, 2.6, 3.0, 3.0, 3.9, 2.94, 2.5, 2.5, 2.7, 3.2, 2.67, 2.0, 2.46], "mode": "markers", "name": "Data"}, {"type": "scatter", "x": [2.63, 3.72, 3.44, 2.73, 2.35, 3.84, 4.0, 3.92, 3.09, 4.0, 3.43, 3.62, 3.49, 3.09, 3.22, 2.52, 2.36, 4.0, 4.0, 4.0, 3.54, 4.0, 3.08, 2.49, 3.6, 3.5, 3.22, null, 3.66, 3.02, 2.84, null, 3.03, 3.49, 3.21, 3.43, 2.63, 2.65, null, 3.98, 2.7, 2.86, 3.91, 3.63, 3.11, 3.34, 3.52, 3.55, 3.47, 3.27, 4.0, 3.9, 2.98, 2.96, null, 3.81, 4.0, 2.71, 3.05, 2.33, 3.38, 3.48, 3.93, 3.45, 3.19, 3.87, 3.28, 3.76, null, 2.75, 4.0, 4.0, 4.0, 2.57, 2.12, 3.41, 4.0, 2.87, 2.97, 3.31, 2.91, 4.0, 3.43, 1.49, 3.71, 3.48, 2.94, 4.0, 2.87, 4.0, 3.04, 3.37, 3.53, 3.75, 3.28, 3.67, 3.95, 4.0, 2.62, 2.77, 3.54, 4.0, 2.32, 2.65, 3.54, 3.03, 3.61, 4.0, 3.79, 1.95, 2.08, 2.18, 3.34, 2.27, 3.79, 2.7, 4.0, 3.94, 3.31, 2.42, 1.89, 4.0, 4.0, 2.26, 2.48, 3.82, 2.93, null, 1.52, 3.3, 3.23, 3.94, 2.46, 2.72, 3.17, 2.81, 2.83, 4.0, 4.0, 3.34, 4.0, 2.69, 2.52, 3.65, 3.45, 2.52, 3.04, 2.8, 4.0, 3.87, 3.73, null, 3.96, 4.0, 2.45, 4.0, 3.46, 3.42, 3.54, 3.48, 3.9, 3.0, 3.32, 2.82, 2.41, 3.9 ...

# %%
print(f"What is the regression equation? College GPA = {slope:.2f} * High School GPA + {intercept:.2f}")
print(f"Does the line fit the pattern of the data well? Moderately well")
print(f"What is college GPA of a high school senior whose GPA is 3.45? {slope * 3.45 + intercept:.2f}")
# Out:
# What is the regression equation? College GPA = 0.62 * High School GPA + 1.07
# Does the line fit the pattern of the data well? Moderately well
# What is college GPA of a high school senior whose GPA is 3.45? 3.21

# %% [markdown]
# **Reporting Results:**
# The scatterplot displays a positive linear relationship between HS GPA and college GPA. The correlation coefficient r is 0.716, indicating that the positive linear relationship is moderately strong.

# %% [markdown]
# #### 3. Conclusion

# %% [markdown]
# - The results are consistent with what can be expected.
# - We should intervene and counsel students while still in high school. Knowing that students with low GPAs are at risk of not doing well in college, colleges should develop programs, such as peer or faculty mentors, for these students.

# %% [markdown]
# ### Q2. Are there differences between males and females with respect to body image?

# %% [markdown]
# #### 1. Reflect on Question
# In this first step, we think about the question and use our intuition and/or experience to try and predict what the results will show. Later, we will compare what we initially thought to what we actually find when we analyze the data.

# %% [markdown]
# >Yes. I think females are more concerned about their body image than men based on my personal experience.
# > Ideally, There is no right or wrong answer here. In the past, body image was a problem associated mostly with females. These days, however, this is no longer the case.

# %% [markdown]
# #### 2. Analyze Data

# %% [markdown]
# ##### a. Plan Analyses

# %% [markdown]
# Before choosing the appropriate analyses, it is helpful to identify the relevant variables, which for this question are:
# - Gender
# - WtFeel
#
# The variable **Gender** is *dependent (explanatory)* variable and is *categorical*.
# The variable **WtFeel** is *independent (response)*  variable and is *categorical*

# %% [markdown]
# ##### b. Exploratory Analysis
# - A meaningful display for this question is *Two-way Table*.
# - A meaningful numerical summary to supplement the above display is *conditional probabilites*
# - Using this display and numerical summary, I will examine relationship between two categorical variables

# %%
two_way_table = pd.crosstab(index=students.Gender, columns=students.WtFeel, margins=True, margins_name='Total')
two_way_table
# Out:
# WtFeel  AboutRt  OverWt  UnderWt  Total
# Gender
# Female      107      32        6    145
# Male         56      15       13     84
# Total       163      47       19    229

# %%
two_way_table.div(two_way_table['Total'], axis=0) * 100
# Out:
# WtFeel    AboutRt     OverWt    UnderWt  Total
# Gender
# Female  73.793103  22.068966   4.137931  100.0
# Male    66.666667  17.857143  15.476190  100.0
# Total   71.179039  20.524017   8.296943  100.0

# %% [markdown]
# #### 3. Conclusion

# %% [markdown]
# The results indicate that males and females do differ with respect to their body image. A larger proportion of females felt that their weight was about right (roughly 74% vs. 67% for males). Among the students who did not feel that their weight was about right, there was a difference between males and females. Roughly the same proportion of male students were concerned about being overweight as being underweight (18% vs. 15.5%), while females were mostly concerned about being overweight (22% vs. only 4% for underweight).
#
# It is interesting to find that actually a larger proportion of males are concerned with their body image compared to females. Also, it makes sense that being underweight is more of a concern for males than it is for females because of the current quest of many males for a big, muscular body and the quest for females to emulate thin fashion models.

# %% [markdown]
# *It would be useful to report these results to people who counsel students, since concerns about body image can result in poor college performance and health issues.*

# %% [markdown]
# ### Q3. Is students' academic performance in college related to their typical seating location in class?

# %% [markdown]
# #### 1. Reflect on Question
# In this first step, we think about the question and use our intuition and/or experience to try and predict what the results will show. Later, we will compare what we initially thought to what we actually find when we analyze the data.

# %% [markdown]
# >One would expect that generally, students who sit in the front or middle of the classroom are the more conscientious students and therefore are also students with higher GPAs. This is of course, a gross generalization. It will be interesting to see whether the data will support this.

# %% [markdown]
# #### 2. Analyze Data

# %% [markdown]
# ##### a. Plan Analyses

# %% [markdown]
# Before choosing the appropriate analyses, it is helpful to identify the relevant variables, which for this question are:
# - GPA
# - Seat
#
# The variable **GPA** is *independent (response)* variable and is *quantitative*.
# The variable **Seat** is *dependent (explanatory)* variable and is *categorical*.

# %% [markdown]
# ##### b. Exploratory Analysis
# - A meaningful display for this question is *Side-by-Side Boxplots*.
# - A meaningful numerical summary to supplement the above display is *descriptive statistics*
# - Using this display and numerical summary, I will compare distribution of a quantitative variable across several groups

# %% [markdown]
# *Side-by-Side Boxplot*

# %%
students.Seat.unique()
# Out:
# array(['M', 'F', 'B'], dtype=object)

# %%
gpa_F = go.Box(y=students.GPA[students.Seat == 'F'], name='Front')
gpa_M = go.Box(y=students.GPA[students.Seat == 'M'], name='Middle')
gpa_B = go.Box(y=students.GPA[students.Seat == 'B'], name='Back')

# %%
layout = go.Layout(
    title='Seating Arragement',
    yaxis={'title': 'GPA'}
)

# %%
iplot(go.Figure(data=[gpa_F, gpa_M, gpa_B], layout=layout))
# Out:
# <div id="8ecbb7fb-cd13-4a1c-b62e-7ea9d15f0b36" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8ecbb7fb-cd13-4a1c-b62e-7ea9d15f0b36", [{"type": "box", "y": [3.0, 3.11, 3.7, 3.5, 3.0, 3.5, 2.62, 3.7, 3.4, 2.8, 3.7, 4.0, 3.22, 3.26, 3.0, 3.71, 3.26, 2.0, 3.876, 3.25, 3.39, 3.4, 3.33, 3.9, 3.8, 3.24, 2.0, 3.44, 2.44, 1.92, 1.96, 3.0, 2.05, 4.0, 3.89, 3.5, 2.67, 3.0, 3.1, 4.1, 3.54, 3.21, 3.3, null, 3.8, 3.0, 3.4, 3.5, 3.6, 3.92, 2.9, 3.9], "name": "Front"}, {"type": "box", "y": [2.6, 2.7, 3.43, 3.77, 3.0, 3.25, 2.83, 3.15, 4.2, 4.38, 3.65, 3.6, 3.0, 2.25, 4.03, 2.54, 2.6, null, 2.93, 3.0, 2.5, 3.0, 3.51, 2.37, null, 3.5, 2.9, 3.9, 2.65, 3.5, 3.3, 3.4, 3.6, 3.21, 3.85, 3.2, 2.5, null, 2.9, 4.2, 2.6, null, 2.01, 3.87, 2.5, 2.9, 3.6, 3.9, 3.2, 3.3, 2.8, 3.8, 3.0, 2.23, 3.01, 2.5, 3.0, 2.79, 3.8, 2.8, 2.64, 3.65, 2.54, 2.8, 3.5, 3.1, 2.66, 1.91, 2.8, 2.8, 2.7, 3.17, 2.6, 2.58, 2.7, 3.5, 3.0, 2.0, 3.34, 3.83, 2.7, 3.9, 2.33, null, 3.0, 3.1, 3.0, 3.0, 3.25, 3.26, 2.1, 2.77, 3.7, null, 3.0, 3.88, 3.0, 3.2, 3.57, 3.0, 2.96, 2.7, 3.8, 2.5, 3.87, 3.4, 3.8, 2.04, 2.8, 2.4, 2.9, 2.38, 3.83, 2.9, 2.91, 3.67, 3.0, 3.5, 3.0, 3.7, 3.33, 4.0, 3.0, 3.2, 3.0, 3.2, 3.4, 3.7, 3.4, 3.1, 3.0, 3.79, 3.81, 2.6, 3.0, 3.0, 3.9], "name": "Middle"}, {"type": "box", "y": [3.4, 3.7, 3.0, 3.2, null, 3.0, 3.1, 2.5, 3.05, 3.5, 2.9, 3.25, 2.58, 2.9, 3.4, 3.92, 3.0, 2.8, 2.84, 2.8, 2.87, 2.95, 4.0, 3.2, 2.5, 3.5, 3.0, 2.9, 2.04, 3.6, 3.4, 4.06, 3.0, 3.43, 2.1, 3.0, 2.06, 3.0, 2.4, 2.94, 2.5, 2.5, 2.7, 3.2, 2.67, 2.0, 2.46], "name": "Back"}], {"title": "Seating Arragement", "yaxis": {"title": "GPA"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
students.groupby('Seat').GPA.describe()
# Out:
#       count      mean       std   min     25%   50%     75%   max
# Seat
# B      46.0  2.974348  0.493296  2.00  2.6775  3.00  3.2375  4.06
# F      51.0  3.251098  0.567237  1.92  3.0000  3.33  3.7000  4.10
# M     131.0  3.118931  0.526408  1.91  2.7800  3.00  3.5050  4.38

# %% [markdown]
# **Reporting Results:**
# When comparing distributions across groups, we need to address the issues of center, spread and outliers:
#
# **Center:** The median GPA of the "F group" (3.33) is higher than that of the two other groups (both of which are 3.0).
#
# **Spread:** Differences in spread between the three groups are not huge, but still exist. The "M group" has the largest spread (range = 2.47, IQR = .74) followed by the "F group" (range = 2.18, IQR = .7), and then the "B group" (range = 2.06, IQR = .58).
#
# **Outliers:** There are no outliers.

# %% [markdown]
# #### 3. Conclusion

# %% [markdown]
# The data suggest that GPA is somewhat related to seating location. In general, the GPAs of students who sit in the front of the classroom are slightly higher than those of students who sit in the middle or in the back. However, there is a lot of variation in GPA within each of the three groups, and therefore the student's typical seating location should not really be used as an indication of his/her performance in college.

# %% [markdown]
# The conclusions support what we would naturally expect. It was interesting to find hardly any differences in GPAs between students who sit in the middle of the classroom and those who sit in the back.
#
# If instructors were made aware of these results, they could encourage students who are doing poorly to change their seat location. Also, students should be made aware that where they sit might impact their performance.
